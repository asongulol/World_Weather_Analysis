# %% [markdown]
# # Generate Random Latitudes and Longitudes

# %%
# Import the random module.
import random

# %%
random.random()
# Out:
# 0.8329335890873136

# %%
random.randint(-10,10)
# Out:
# -6

# %%
random.randrange(-9,9,2)
# Out:
# -7

# %%
random.uniform(-10, 10)
# Out:
# 8.294402827130373

# %% [markdown]
# ![random%20numbers%20in%20python.PNG](attachment:random%20numbers%20in%20python.PNG)

# %% [markdown]
# ## The NumPy and random Modules
#
# One way to generate more than a thousand latitudes and longitudes is to chain the NumPy module to the random module to create an array of latitudes or longitudes between the lowest and highest values, or –90° and 90°, and –180° and 180°, respectively. To accomplish this, we’ll use the uniform() function from the random module.

# %% [markdown]
# ## The randint() Function
#
# randint is short for “random integer.” In the second cell, after random., type randint(-90, 90), as shown below.

# %%
random.randint(-90,90)
# Out:
# -16

# %% [markdown]
# ### The random() Function
#
# Using the random() function, we can get a single floating-point decimal number between 0 and 1.0.
#
# Add random.random() to a new cell and run the cell. Your output should be a decimal point number between 0 and 1.0, as shown below.

# %%
random.random()
# Out:
# 0.8636129664070383

# %% [markdown]
# ### Combining random() and randint()
# The random() function may help us. This function returns only a floating-point decimal number between 0 and 1.0. If we combine random.randint(-90, 89) and random.random() to generate a floating-point decimal between –90 and 90, we can generate a random latitude. We changed the lower range of the randint() because we want whole numbers up to 89, so when we add the floating-point decimal number, we’ll generate latitudes between –89.99999 and 89.99999.
#
# Using these two functions, we can write an algorithm that will generate latitudes between –90 and 89. Here is a small sample of what it might take to generate ten random floating-point decimal latitudes between –90 and 89.

# %% [markdown]
# ## Generate Random Latitudes and Longitudes
#
# Before we write the algorithm to generate the latitudes and longitudes, we need to refresh our memory of where people live in the world. Time for another quick geography lesson!
#
# Earth’s surface is covered by 70% water while the rest is covered by land. So, we can assume 70% of the latitude and longitude coordinates we generate are positioned over a body of water, whether an ocean, major lake (e.g., Lake Superior), or major river (e.g., Amazon). Geographic coordinates over a body of water may not be close to a city, especially if in the middle of an ocean.
#
# Seven continental landmasses comprise 30% of Earth’s surface. Some land is uninhabitable or sparsely populated due to extreme terrain and climes (e.g., Sahara, Siberia, the Himalayas, and areas of the western United States).
#
# First consider the bodies of water. Start with at least 1,500 latitudes and longitudes, because 500 divided by 0.3 (30% land mass) equals 1,666 latitudes and longitudes.
#
# We’ll generate random latitudes and longitudes to ensure coordinates are fairly distributed around the world. An algorithm will pick random numbers between the low and high values for latitudes and longitudes. Also, the latitudes and longitudes must be floating-point decimal numbers, as each angular unit of degrees, minutes, and seconds can be represented by a decimal number. For example, Kailua-Kona, Hawaii has the angular coordinates 19° 38' 23.9784'' north and 155° 59' 48.9588'' west and can be written as a decimal number as follows: 19.639994, -155.996933.
#
# To generate random numbers, we can use the Python random module. This module is part of the Python and Anaconda installation, so we don’t need to install it. Let’s test some random module functions to find one that can help us.

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [-34.532878303041976,
#  -78.65349515761089,
#  1.5946788329168164,
#  81.53574950107823,
#  -13.282616441853861,
#  43.84059435690578,
#  -35.86316273776268,
#  -10.705062526955984,
#  44.30011040199303,
#  49.12323284397738]

# %% [markdown]
# In the code block above, we:
#
# 1. Assign the variable x to 1.
# 2. Initialize an empty list, latitudes.
# 3. We create a while loop where we generate a random latitude and add it to the list.
# 4. After the random latitude is added to the list we add one to the variable “x”.
# 5. The while loop condition is checked again and will continue to run as long as x is less than 11.

# %% [markdown]
# Next, we would have to use a similar method to get random longitudes between –180 and 180, which we can then pair with the latitudes. This looks promising, but the code to generate the latitudes above is a little long.
#
# Let’s try another function, the randrange() function.

# %% [markdown]
# ## The randrange() Function
# The randrange() function behaves differently than the previous two functions. Inside the parentheses, we need to add two numbers, a lower and upper limit, separated by a comma.
#
# For the randrange() function, there is an option to add a step parameter and set it equal to an integer, which will generate increments of a given integer value, from the lower to the upper limit.
#
# For example, add random.randrange(-90, 90, step=1) to a new cell and run the cell. The output is a number between -90 and 90, where the step is the difference between each number in the sequence.

# %% [markdown]
# Now add random.randrange(-90, 90, step=3) to a new cell and run the cell. The output is a number between -90 and 90, where the difference between each number in the sequence is 3.

# %%
# adding the step= variable specifies a step of 3 digits in the sequence

random.randrange(-90, 90, step=3)
# Out:
# 18

# %% [markdown]
# ## The uniform() Function
#
# The uniform() function will allow us to generate a floating-point decimal number between two given numbers inside the parentheses.
#
# Add random.uniform(-90, 90) to a new cell and run the cell. The output should look like the following:

# %%
random.uniform(-90, 90)
# Out:
# 58.82906436633908

# %% [markdown]
# ## The NumPy and random Modules
# One way to generate more than a thousand latitudes and longitudes is to chain the NumPy module to the random module to create an array of latitudes or longitudes between the lowest and highest values, or –90° and 90°, and –180° and 180°, respectively. To accomplish this, we’ll use the uniform() function from the random module.

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 10.433568128958882

# %% [markdown]
# When we use the NumPy module with the random.uniform() function, the parenthetical parameters contain a lower boundary (low value) and an upper boundary (high value) that are floating-point decimal numbers.

# %% [markdown]
# To generate more than one floating-point decimal number between –90 and 90, we can add the size parameter when we use the NumPy module and set that equal to any whole number.
#
# To see how this works, add the code np.random.uniform(-90.000, 90.000, size=50) to a new cell and run the cell. The output is an array of 50 floating-point decimal numbers between –90.000 and 90.000.

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([  1.6338195 , -11.68207347,  88.8474368 ,  61.48075001,
#        -22.15051847, -32.40389937,  60.71486973,  -1.68386999,
#         32.81309436,  56.6199855 , -68.33584359,  86.54612965,
#         38.86123188,  24.59196059,  33.0683832 ,  -8.5215548 ,
#        -63.38823332, -17.93197671,  81.42101181,  61.50152098,
#        -66.62491987,  80.69492606,  69.33925424, -52.47212814,
#        -84.60240871,  -7.71491058, -82.85450006,  -5.27248176,
#        -73.70443027, -23.31993542, -47.30301469, -75.63045891,
#        -35.41740907,  84.81651676, -37.18284716,   3.20482411,
#          5.60764582,  11.45021217,  85.82167668,  -5.62253763,
#        -87.50252735, -11.08670521,  32.17473239, -22.08597752,
#         86.347859  ,  63.98414731,  51.91970383,  79.17902567,
#        -54.70989326, -70.42182893])

# %% [markdown]
# Now we are getting somewhere—all we need to do is increase the parameter size to 1,500.
#
# Is this method faster than creating a while loop like we did before? Let’s test this for a size of 1,500.
#
# To test how long a piece of code or function takes to run, we can import the “timeit” module and use the %timeit magic command when we run our code or call the function.
#
# First, import the timeit module in a new cell, and run the cell.

# %%
# Import timeit.
import timeit

# %%
#add the %timeit magic command before the np.random.uniform(-90.000, 90.000, size=1500) i
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 11.8 µs ± 63.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# Now, let’s run the while loop as a function. Copy the following code in a new cell and run the cell

# %%
# Call the function with 1500 variables

def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500. 
# %timeit latitudes(1500)
# Out:
# 1.49 ms ± 7.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# Using the np.random.uniform(-90.000, 90.000, size=1500) is 100 times faster than using the function, and our code is one line, whereas the function uses eight lines!

# %% [markdown]
# ### __Skill Drill__
#
# Refactor the code for the while loop with the %timeit magic command and write a for loop that will generate the 1,500 latitudes.

# %% [markdown]
# ## Create Latitude and Longitude Combinations
#
# Let’s apply our new knowledge to this project. Create a new Jupyter Notebook file called
#
# WeatherPy.ipynb, import the Pandas, Matplotlib, and NumPy dependencies in the first cell, and run the cell.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %% [markdown]
# In the next cell, we’ll add the code that generates the latitudes and longitudes, but first, they need to be stored so that we can access them later. Since we are creating arrays of latitudes and longitudes, we’ll declare each array as a variable.
#
# In the next cell, add the following code that we used to generate the random latitudes. Also, we’ll create a similar code snippet that will generate longitudes. To ensure enough latitudes and longitudes, we’ll start with 1,500. In addition, we’ll pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
coordinates
# Out:
# [(36.88334549134578, -81.37496461387546),
#  (65.95098163989496, -72.65031168285174),
#  (89.74273910511019, 11.565610671802347),
#  (-36.575043617761146, -108.81330364912164),
#  (-55.9903676980576, -43.13314961453247),
#  (-63.07341248814973, -144.55742290520874),
#  (-55.68528537216218, -120.60409081820532),
#  (-20.55747002649632, 132.8667346541523),
#  (23.467682912395134, -110.87328148896495),
#  (14.550879739502577, 93.94184830898212),
#  (45.3808433772511, -74.3013632927848),
#  (-11.157568683146607, -45.472253460012325),
#  (-10.543942307954353, 76.84981343225417),
#  (-76.6847834344879, 127.17727595955967),
#  (-10.254173586536382, -93.1680105293894),
#  (81.01076060770632, 9.637232237288316),
#  (-51.98327611298784, 44.74373093853808),
#  (55.803536849764384, -105.07853634901485),
#  (-58.84545931596719, -87.18880805376682),
#  (-37.02105458134519, -9.744504681983642),
#  (7.069222391634469, 146.71535991271406),
#  (-9.156568224690346, 107.69939672035275),
#  (-34.77722990487955, 78.54510248910236),
#  (-82.52221001269679, -88.33942937517357),
#  (73.46968551521178, -37.679928207435154),
#  (-85.74764238162409, 154.78139693676883),
#  (-54.9077937929012, -40.71392604273214),
#  (-67.92477773346093, -174.3273936641528),
#  (48.71382057012417, -6.567279935965814),
#  (-69.61511677166504, 103.78631940706669),
#  (-36.422129054127105, -91.98596952254714),
#  (11.228682278310544, -113.97661561062111),
#  (-78.51432913242385, -68.49735029469727),
#  (5.521360280018257, -74.460099909031),
#  (9.470840612955456, -134.29500096207144),
#  (-58.9923859957275, -86.41584061747297),
#  (-70.3522132807398, 30.929159616741288),
#  (70.31817230624236, 96.97084260458348),
#  (82.87475277531581, 144.00893383686292),
#  (-13.573302482939084, -15.758066940307174),
#  (-12.94671443386197, 27.30727277509348),
#  (-36.813897952608535, -93.75624470789857),
#  (-60.59402773606433, 67.65080701341446),
#  (-53.60083427844905, -38.17463771705073),
#  (2.255779956394761, 21.806536111724057),
#  (-86.75544864447544, -68.96868455747597),
#  (29.406755112328483, -168.3086142299043),
#  (-60.174687764417904, -98.33267995856473),
#  (38.53620846003895, -129.10131865213532),
#  (51.934570419492246, 82.99189604450584),
#  (-42.10572427819751, -31.67247199551244),
#  (53.31246903639652, -124.73234970558693),
#  (-52.32554143102816, 17.081167637535486),
#  (83.92833994070767, -107.5425386062134),
#  (44.66302596881749, -18.71917203600924),
#  (-4.907992322917806, 2.673373477659453),
#  (70.91229457611428, -28.551175307116324),
#  (-81.54825130296294, -11.207521978827486),
#  (-46.02558655547385, -111.38155083539992),
#  (-60.490968238483546, -25.390123372120826),
#  (-35.472399029649715, -102.9585531284524),
#  (44.39196007227477, 173.93530781716652),
#  (12.467872627206148, 86.76698581959101),
#  (-54.52508139757279, 45.44637528469451),
#  (-87.51612858316649, 171.40045440709662),
#  (7.751911804718489, 99.60313175325831),
#  (58.00127152429798, 97.52081806288578),
#  ...]

# %% [markdown]
# # 6.1.5 Generate Random World Cities
#
# With our list of random latitudes and longitudes, we’ll use the coordinates in our lat_lngs tuple to find the nearest city using Python’s citipy module.
#
# Since we haven’t worked with the citipy module yet, let’s import and test it. Citipy doesn't come with the Anaconda module, so we’ll install it in our PythonData environment.
#
# The citypy documentation (Links to an external site.) instructs us to install the citipy module by typing pip install citipy. To complete the installation, follow the instructions for your operating system.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %% [markdown]
# Some of this code should look familiar, but let’s break it down:
#
# We create a cities list to store city names.
# We iterate through the coordinates, as in our practice, and retrieve the nearest city using the latitude and longitude pair.
# We add a decision statement with the logical operator not in to determine whether the found city is already in the cities list. If not, then we’ll use the append()function to add it. We are doing this because among the 1,500 latitudes and longitudes, there might be duplicates, which will retrieve duplicate cities, and we want to be sure we capture only the unique cities.

# %%
cities
# Out:
# ['bluefield',
#  'iqaluit',
#  'barentsburg',
#  'rikitea',
#  'mar del plata',
#  'mataura',
#  'alice springs',
#  'todos santos',
#  'labutta',
#  'rigaud',
#  'formosa do rio preto',
#  'hithadhoo',
#  'new norfolk',
#  'puerto ayora',
#  'east london',
#  'la ronge',
#  'punta arenas',
#  'jamestown',
#  'lorengau',
#  'kawalu',
#  'bambous virieux',
#  'tasiilaq',
#  'bluff',
#  'vaini',
#  'penzance',
#  'albany',
#  'lebu',
#  'san patricio',
#  'ushuaia',
#  'yacopi',
#  'atuona',
#  'port elizabeth',
#  'khatanga',
#  'chokurdakh',
#  'georgetown',
#  'tuatapere',
#  'haines junction',
#  'srednekolymsk',
#  'vardo',
#  'katsuura',
#  'pevek',
#  'omboue',
#  'dovers',
#  'kargasok',
#  'taolanaro',
#  'nizwa',
#  'victoria',
#  'nanortalik',
#  'ribeira grande',
#  'saskylakh',
#  'butaritari',
#  'husavik',
#  'wadena',
#  'ugoofaaru',
#  'takob',
#  'lagoa',
#  'bredasdorp',
#  'tiksi',
#  'hilo',
#  'mercedes',
#  'weyburn',
#  'cidreira',
#  'naze',
#  'upernavik',
#  'hovd',
#  'palmas',
#  'hihifo',
#  'severo-kurilsk',
#  'necochea',
#  'busselton',
#  'carnarvon',
#  'ponta do sol',
#  'berdigestyakh',
#  'port alfred',
#  'yatou',
#  'cape town',
#  'kavieng',
#  'ternate',
#  'humaita',
#  'belushya guba',
#  'atambua',
#  'amderma',
#  'norman wells',
#  'leningradskiy',
#  'san ramon',
#  'bethel',
#  'tumannyy',
#  'torbay',
#  'zhangye',
#  'dikson',
#  'puerto maldonado',
#  'chuy',
#  'cross lanes',
#  'puerto narino',
#  'tabiauea',
#  'kalmunai',
#  'byron bay',
#  'vestmannaeyjar',
#  'kandrian',
#  'erenhot',
#  'kapaa',
#  'faya',
#  'pangnirtung',
#  'quelimane',
#  'manzhouli',
#  'cururupu',
#  'camacha',
#  'formoso do araguaia',
#  'kasongo-lunda',
#  'baie-comeau',
#  'vila franca do campo',
#  'krasnoyarsk-45',
#  'longhua',
#  'constitucion',
#  'hobart',
#  'namibe',
#  'tura',
#  'doha',
#  'mawlaik',
#  'bengkulu',
#  'aklavik',
#  'gao',
#  'correntina',
#  'urengoy',
#  'forbes',
#  'barrow',
#  'mirabad',
#  'westport',
#  'shasta lake',
#  'sao filipe',
#  'tautira',
#  'thompson',
#  'harstad',
#  'loiza',
#  'alibag',
#  'ancud',
#  'atar',
#  'kropotkin',
#  'jalu',
#  'west wendover',
#  'artyk',
#  'bonthe',
#  'khonuu',
#  'aleksandrov gay',
#  'vaitupu',
#  'zdolbuniv',
#  'hambantota',
#  'kysyl-syr',
#  'alofi',
#  'chunskiy',
#  'lompoc',
#  'imbituba',
#  'ambodifototra',
#  'hermanus',
#  'vao',
#  'saint george',
#  'half moon bay',
#  'samusu',
#  'gat',
#  'bargal',
#  'deputatskiy',
#  'hobyo',
#  'shihezi',
#  'castro',
#  'avera',
#  'porto novo',
#  'tlaxco',
#  'vanimo',
#  'padang',
#  'pozo colorado',
#  'delta del tigre',
#  'kloulklubed',
#  'deniliquin',
#  'marystown',
#  'niigata',
#  'longyearbyen',
#  'vryburg',
#  'airai',
#  'florencia',
#  'temaraia',
#  'grand gaube',
#  'salalah',
#  'garowe',
#  'fortuna',
#  'basudebpur',
#  'arraial do cabo',
#  'hasaki',
#  'ferkessedougou',
#  'flinders',
#  'wulanhaote',
#  'avarua',
#  'madera',
#  'las vegas',
#  'kilakarai',
#  'alta floresta',
#  'ponta delgada',
#  'saint-francois',
#  'port hardy',
#  'nikolskoye',
#  'oktyabrskiy',
#  'qaanaaq',
#  'asyut',
#  'belgrade',
#  'tuktoyaktuk',
#  'progreso',
#  'winnemucca',
#  'kerman',
#  'nantucket',
#  'kaitangata',
#  'sitka',
#  'ngukurr',
#  'lerwick',
#  'vila do maio',
#  'saleaula',
#  'mbaiki',
#  'owando',
#  'pisco',
#  'gogrial',
#  'yerbogachen',
#  'quatre cocos',
#  'pitimbu',
#  'rio gallegos',
#  'labuhan',
#  'souillac',
#  'udachnyy',
#  'te anau',
#  'lima',
#  'san policarpo',
#  'kodiak',
#  'chalus',
#  'savannah bight',
#  'orlik',
#  'vila velha',
#  'port lincoln',
#  'mount gambier',
#  'palabuhanratu',
#  'adrar',
#  'klaksvik',
#  'acarau',
#  'nouadhibou',
#  'marcona',
#  'catuday',
#  'bella vista',
#  'buseresere',
#  'broome',
#  'sao joao da barra',
#  'fairbanks',
#  'esperance',
#  'channel-port aux basques',
#  'wuda',
#  'guilin',
#  'saint-pierre',
#  'college',
#  'dongsheng',
#  'richards bay',
#  'garmsar',
#  'sao felix do xingu',
#  'austin',
#  'ishigaki',
#  'tsihombe',
#  'sentyabrskiy',
#  'isangel',
#  'muriti',
#  'illoqqortoormiut',
#  'tabou',
#  'dubai',
#  'mayo',
#  'mahebourg',
#  'narsaq',
#  'saldanha',
#  'kyzyl-suu',
#  'saint-philippe',
#  'yellowknife',
#  'moerai',
#  'brae',
#  'hamilton',
#  'west lorne',
#  'najran',
#  'faanui',
#  'adana',
#  'tual',
#  'dunedin',
#  'kranea elassonos',
#  'chicama',
#  'soe',
#  'mount isa',
#  'kenai',
#  'muriwai beach',
#  'okhotsk',
#  'mayya',
#  'scottsbluff',
#  'birao',
#  'nalut',
#  'edson',
#  'geraldton',
#  'barawe',
#  'grindavik',
#  'arman',
#  'ciudad guayana',
#  'tete',
#  'santa isabel do rio negro',
#  'sisimiut',
#  'ketchikan',
#  'kuruman',
#  'xiaoweizhai',
#  'togur',
#  'severo-yeniseyskiy',
#  'yulara',
#  'ewa beach',
#  'juneau',
#  'moctezuma',
#  'asenovgrad',
#  'sola',
#  'urcos',
#  'flin flon',
#  'broken hill',
#  'nome',
#  'ahipara',
#  'lazaro cardenas',
#  'medicine hat',
#  'touros',
#  'yar-sale',
#  'fukue',
#  'pierre',
#  'sabang',
#  'belyy yar',
#  'chapais',
#  'rocha',
#  'cabra',
#  'krasnoborsk',
#  'inongo',
#  'lolua',
#  'tateyama',
#  'paamiut',
#  'ambulu',
#  'saint-augustin',
#  'mezen',
#  'grand river south east',
#  'pueblo bello',
#  'rolim de moura',
#  'nisia floresta',
#  'bilma',
#  'mackenzie',
#  'wattegama',
#  'taoudenni',
#  'zhigansk',
#  'cabo san lucas',
#  'luderitz',
#  'port moresby',
#  'rafai',
#  'xiongzhou',
#  'carlos antonio lopez',
#  'arsikere',
#  'belmonte',
#  'palo alto',
#  'azuaga',
#  'guarda',
#  'stornoway',
#  'codrington',
#  'gamba',
#  'klyuchi',
#  'dembi dolo',
#  'wanning',
#  'pacific grove',
#  'anadyr',
#  'kruisfontein',
#  'cayenne',
#  'ukiah',
#  'kerns',
#  'meulaboh',
#  'sangar',
#  'ongandjera',
#  'palmerston',
#  'santa isabel',
#  'vostok',
#  'port macquarie',
#  'ilulissat',
#  'darhan',
#  'sioux lookout',
#  'safwah',
#  'alpena',
#  'sur',
#  'hervey bay',
#  'mys shmidta',
#  'huarmey',
#  'nizhneyansk',
#  'caravelas',
#  'camopi',
#  'falealupo',
#  'socorro',
#  'nelson bay',
#  'yumen',
#  'chakia',
#  'prince rupert',
#  'mayumba',
#  'punta cardon',
#  'divnoye',
#  'jujuy',
#  'sale',
#  'hofn',
#  'manjeshwar',
#  'lakes entrance',
#  'katangli',
#  'yunjinghong',
#  'kahului',
#  'poum',
#  'sakakah',
#  'cherskiy',
#  'redmond',
#  'murchison',
#  'ambovombe',
#  'taksimo',
#  'dakar',
#  'marathon',
#  'srednebelaya',
#  'wabash',
#  'vysokogornyy',
#  'karratha',
#  'rangpo',
#  'jacareacanga',
#  'mrirt',
#  'saint-joseph',
#  'borogontsy',
#  'anori',
#  'sergeyevka',
#  'goderich',
#  'tamandare',
#  'muli',
#  'trelew',
#  'santa margherita ligure',
#  'chingola',
#  'lisala',
#  'ust-kalmanka',
#  'vanderhoof',
#  'port blair',
#  'huai yot',
#  'boguchany',
#  'haldensleben',
#  'gizo',
#  'puerto cabezas',
#  'lasa',
#  'roald',
#  'alberton',
#  'san juan',
#  'baoshan',
#  'kuito',
#  'fort frances',
#  'muravlenko',
#  'cockburn town',
#  'yeppoon',
#  'bronnoysund',
#  'pemba',
#  'puerto escondido',
#  'peniche',
#  'ostrovnoy',
#  'higuey',
#  'torbat-e jam',
#  'nauchnyy gorodok',
#  'mehamn',
#  'nizhnevartovsk',
#  'pemberton',
#  'umzimvubu',
#  'skjervoy',
#  'sterling',
#  'provideniya',
#  'mata',
#  'kilim',
#  'daru',
#  'bereznik',
#  'xuddur',
#  'sobolevo',
#  'newport',
#  'deville-les-rouen',
#  'noumea',
#  'surt',
#  'capreol',
#  'emerald',
#  'tigil',
#  'mier',
#  'ulyanovo',
#  'road town',
#  'kutum',
#  'madimba',
#  'kibaya',
#  'hualmay',
#  'kautokeino',
#  'coquimbo',
#  'shirokiy',
#  'tres arroyos',
#  'clyde river',
#  'attawapiskat',
#  'hami',
#  'libreville',
#  'aykhal',
#  'manono',
#  'formosa',
#  'kununurra',
#  'treinta y tres',
#  'ossora',
#  'mastic beach',
#  'zacatepec',
#  'bonfim',
#  'korla',
#  'sydney',
#  'mocuba',
#  'camacari',
#  'znamenskoye',
#  'ofaqim',
#  'sinnamary',
#  'douglas',
#  'guerrero negro',
#  'castelo branco',
#  'krasnoselkup',
#  'rafaela',
#  'tulun',
#  'alsfeld',
#  'springbok',
#  'muros',
#  'lithgow',
#  'lesozavodsk',
#  'coihaique',
#  'issoire',
#  'makakilo city',
#  'vila',
#  'tomakomai',
#  'grenaa',
#  'pangai',
#  'itaqui',
#  'maloshuyka',
#  'tilichiki',
#  'arlit',
#  'high level',
#  'dolores',
#  'namatanai',
#  'lircay',
#  'oxford',
#  'sault sainte marie',
#  'isiro',
#  'malaya serdoba',
#  'dingle',
#  'ekhabi',
#  'tessalit',
#  'alamosa',
#  'olafsvik',
#  'paranaiba',
#  'north battleford',
#  'praia da vitoria',
#  'kharp',
#  'esso',
#  'muroto',
#  'kirakira',
#  'santa fe',
#  'lanigan',
#  'hunza',
#  'nuuk',
#  'amatlan',
#  'aranos',
#  'hanzhong',
#  'zaysan',
#  'uporovo',
#  'asau',
#  'mackay',
#  'dergachi',
#  'grants',
#  'kakonko',
#  'fort nelson',
#  'bansko',
#  'rondonopolis',
#  'seoul',
#  'beidao',
#  'preobrazheniye',
#  'felanitx',
#  'alquizar',
#  'manadhoo',
#  'boende',
#  'hakvik',
#  'virginia beach',
#  'koshurnikovo',
#  'trat',
#  'cabo rojo',
#  'meridian',
#  'chinsali',
#  'bulaevo',
#  'utiroa',
#  'north bend',
#  'jonuta',
#  'igrim',
#  'chifeng',
#  'bunbury',
#  'bhuj',
#  'ouesso',
#  'pontianak',
#  'gejiu',
#  'majene',
#  'nemuro',
#  'campbell river',
#  'kamaishi',
#  'maniitsoq',
#  'dalbandin',
#  'opuwo',
#  'beaverlodge',
#  'camocim',
#  'cap malheureux',
#  'margate',
#  'banjarmasin']

# %% [markdown]
# Some of this code should look familiar, but let’s break it down:
#
# 1. We create a cities list to store city names.
# 2. We iterate through the coordinates, as in our practice, and retrieve the nearest city using the latitude and longitude pair.
# 3. We add a decision statement with the logical operator not in to determine whether the found city is already in the cities list. If not, then we’ll use the append()function to add it. We are doing this because among the 1,500 latitudes and longitudes, there might be duplicates, which will retrieve duplicate cities, and we want to be sure we capture only the unique cities.
# NOTE

# %% [markdown]
# __NOTE__
# When you run the code block, you should get slightly more than 500 unique cities. If you get fewer than 500, increase your size limit on the np.random.uniform() function.

# %% [markdown]
# # 6.2.1 Understanding APIs
#
# When a client uses our company’s website to search for hotels, our search engine will gather information from a variety of websites based on the client’s preferences through APIs. An API call is very similar to navigating to a website. An API points to a URL and collects some data from the webpage or server.
#
# When clients request information from our server through our website, they are making an API call. Once our database has the client’s search criteria, our servers search the web for hotels on behalf of the client. Now the roles are reversed: our company is the client requesting information, and all the websites where we derive information are the servers.
#
# Using an API has its limitations because not all information from a server is accessible. Most APIs have tiered services, from free to paid. Free services allow access to limited information, and paid subscriptions provide more access based on the payment plan. Our company has a paid subscription for APIs, but we can only get certain information from websites on hotels such as location, accessibility, rooms, prices, services, and amenities, as well as regional weather data.
#
# Now that you have a general concept of how APIs work, let’s register for an OpenWeatherMap API key, a token granting access, and use it to retrieve weather data.

# %% [markdown]
# ## Register for an API Key
# Follow these steps to register for an OpenweatherMap API key:
#
# 1. Navigate to the OpenWeatherMap website (Links to an external site.).
# 2. Click “Sign Up.”
# 3. The login/sign-up page for the OpenWeatherMap API
# 4. Complete the form Create New Account.
# 5. Once you have a new account, sign in and click on “API keys.” The options page for the OpenWeatherMap API, with an arrow pointing to the “API keys” tab
#
#     - The site will likely generate an API key automatically. If not, u nder “Create key,” type a name in the available cell and click “Generate” to create an API key.
#     - The screen where you create an API key on the OpenWeatherMap API webpage with the “Key” field and the “Generate” button shown
#
# 6. Save your API key to a Python file, which we’ll add as a dependency to your WeatherPy.ipynb file.
# 7. Navigate to your World_Weather_Analysis folder and launch Jupyter Notebook.
# 8. Click the New button and select Text File.
# 9. Rename the text file config.py.
# 10. On the first line, type weather_api_key="" and add your API key between the double quotation marks.
# 11. Save and close the config.py file.
#
# __NOTE__
#
# You can also create the config.py file using VS Code.
#
# __IMPORTANT__
# Don’t share your API key with anyone and do not add the config.py file to your GitHub repository—someone might copy and use it and you could incur charges on your credit card.
#
# Click on “Services” for details on your free subscription and its limitations.
# The “Services” tab on the menu showing the free plan services for the OpenWeatherMap API
#
# Click on “View” to see more options on your plan, and then click on “Current weather API” to see how to get the current weather from a city.

# %% [markdown]
# ## The JavaScript Object Notation (JSON) Format for API Data
#
# The API has reached the website or server, its endpoint, and now we can retrieve data from the website. When we retrieve data from a website, we have to make a “request,” which returns data in a text format, not in a tab- or comma-separated file.
#
# One format we can use to parse data is JavaScript Object Notation (JSON). The JSON format is also referred to as an “object” or “JSON object.” The data inside a JSON object opens and closes with curly braces, much like a Python dictionary. Inside the JSON object is a collection of dictionaries and arrays.
#
# Below is an example of what weather data looks like in the JSON format when we request it from the OpenWeatherMap website. There are curly braces that wrap the data, and inside the curly braces are dictionaries and arrays.

# %% [markdown]
# ![json%20example.png](attachment:json%20example.png)

# %% [markdown]
# ## The Python Requests Library
#
# To request JSON data over the internet, we use the Requests Library in Python. The Anaconda installation comes with version 2.22 of the Requests Library.
#
# Confirm you have the latest version of the Requests Library using the command line, or in the Jupyter Notebook environment. Follow the instructions for your operating system.

# %% [markdown]
# ### Windows
# 1. Launch the Anaconda Prompt for your PythonData environment.
# 2. After the Python prompt, >, type python to launch Python.
# 3. At the Python prompt, >>>, type import requests and press Enter.
# 4. On the next line type requests.__version__ and press Enter.
# 5. The output should be version 2.22.0 or later.
#
# Alternatively, you can check the version of request in Jupyter Notebook.
#
# In Jupyter Notebook, create a new file if one hasn’t been created. Add the following code to the new cell and run it.
#
# The output should be 2.22.0 or later.
#
# If you have an older version, please upgrade it in your PythonData environment by typing conda install -c conda-forge requests, at the command prompt and press Enter.

# %% [markdown]
# ## 6.2.3 Make an API Call
#
# In our API_practice file, add a new cell after the code we wrote to get the unique cities from with the citipy module. In the new cell, we will import the Requests Library and your API key from the config.py file.
#
# __NOTE__
# Your config.py file should be in the same folder as your API_practice.ipynb file or any Jupyter Notebook file that is accessing the config.py file.
#
# Add the following code to the new cell and run the cell.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %% [markdown]
# Before we make an API call for the OpenWeatherMap, we need to use the URL provided on the OpenWeatherMap website.
#
# Let’s look at the documentation on the OpenWeatherMap website.
#
# 1. Navigate to the OpenWeatherMap website (Links to an external site.).
# 2. Click “Guide” in the top navigation menu.
# The navigation menu on the OpenWeatherMap website, with an arrow pointing to the “Guide” tab
# 3. From the Guide menu, select the “II. API Documentation” section.
# The table of contents available in the “Guide” menu.
#
# The API documentation section provides instructions on how to make the API call by city name. The structure of our URL should look like the following:
#
# api.openweathermap.org/data/2.5/weather?q=city&appid=b6907d289e10d714a6e88b30761fae22
#
# 4. Add your API key and the city from the cities array for each call.
# The API documentation with the example of an API endpoint selected
#
# Next let’s practice making an API call and look at the data returned from the API call. Add the following code to a new cell and run the cell.

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a0611b21d8ae50da7474a70ec8de5bfa

# %% [markdown]
# If you notice, we added another feature to the URL: units=Imperial. There are three unit options: standard, metric, and imperial. Navigating to current weather data page (Links to an external site.) will show you the options for the unit format.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# The resulting link is a JSON file for the call
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a0611b21d8ae50da7474a70ec8de5bfa&q=Boston

# %% [markdown]
# In the code, we are creating a string to get the weather data for Boston by using the city_url. To create the city_url we add the parameter, &q= and “Boston” to the url.
#
# The output of this cell will also be a URL. Click the URL and a new window will open in your default web browser that shows the current weather data for Boston.

# %% [markdown]
# # 6.2.4 Make a Request for Data to an API

# %% [markdown]
# ## Retrieve a Response Using the get() Method
#
# Use the get() method, a feature of the Requests Library, to request data from an API. The get() method is one of many HTTP methods that allow us to access, add, delete, get the headers, and perform other actions on the request.
#
# Below is a list of HTTP methods and their uses. For more information, see the Requests Library (Links to an external site.).
# ![API%20commands.PNG](attachment:API%20commands.PNG)

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# The code output will be __<Response [200]>__, indicating a valid response. We won’t see this code when a website appears in a browser. However, when a website does not appear, we’ll see a __404 code__, indicating a client error.

# %% [markdown]
# You can directly call the response code with the get() method using the status_code. If we chain the status_code to the city_weather variable, we get 200 as the output.
#
# If we tried to get weather data from an unrecognized city, or if the weather data for a city wasn’t available, we would get a 404 response.
#
# Let’s see what would happen if we misspelled a city name—“Bston” instead of “Boston.” Add the following code to a new cell and run the cell.

# %%
# Create an endpoint URL for a city NOTE misspelling the name of the city 
#results in a 404 respons
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %% [markdown]
# ## Get Data from a Response
# Now, we’ll see what happens when we get a valid response.
#
# In a new cell, correct the spelling for the city of “Boston” to create the city_url.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# When we receive a valid response from the server, we have to decide on the data format. The options are text, JSON, XML, or HTML format. We can apply the format attributes to get the data into a useful format to parse.
#
# One format that provides a preview of the JSON data is the text attribute. Let’s get the content for the Boston weather data using the following code.

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"base":"stations","main":{"temp":72.12,"feels_like":71.38,"temp_min":68,"temp_max":75,"pressure":1007,"humidity":73},"visibility":16093,"wind":{"speed":9.17,"deg":180},"rain":{"1h":0.42},"clouds":{"all":90},"dt":1593293787,"sys":{"type":1,"id":3486,"country":"US","sunrise":1593248969,"sunset":1593303907},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %% [markdown]
# The text in the output is a dictionary of dictionaries and arrays, or a JSON file. We can work with this data, but it might be more challenging if we needed to retrieve temperature (temp) and humidity ( humidity) from this output because the data is in a sentence format.
#
# Let’s use the json() attribute with our response and run the cell.

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 72.12,
#   'feels_like': 71.38,
#   'temp_min': 68,
#   'temp_max': 75,
#   'pressure': 1007,
#   'humidity': 73},
#  'visibility': 16093,
#  'wind': {'speed': 9.17, 'deg': 180},
#  'rain': {'1h': 0.42},
#  'clouds': {'all': 90},
#  'dt': 1593293787,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1593248969,
#   'sunset': 1593303907},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# ## Handle Request Errors
#
# When we submit a get request for the city_weather, we want to make sure that we get a valid response, i.e., 200, before we retrieve any data. To check if we get a valid response, we can write a conditional expression that will evaluate whether the status code is equal to 200. If it is, then we can print out a statement that says the weather data was found. If there is a response other than 200, we can print out a statement that says the weather was not found, as in the following example:

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %% [markdown]
# __NOTE__
# If the status_code is something other than 200, JSON data will always be returned in the request. We can determine if the response was successful by checking the status_code, clicking the URL, or retrieving specific information from the JSON data.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %% [markdown]
# The output for this code is City weather found.
#
# However, if we type print(city_url) in a new cell and run the cell, the output will be a URL. If we click the URL, the web browser returns a 404 response and there is no data to retrieve.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a0611b21d8ae50da7474a70ec8de5bfa&q=Bston

# %% [markdown]
# # 6.2.5 Parse a Response from an API
#
# For each city in our lats_lngs list, we need to retrieve the following data and add it to a DataFrame:
#
# - City, country, and date
# - Latitude and longitude
# - Maximum temperature
# - Humidity
# - Cloudiness
# - Wind speed
#
# Our final DataFrame should look like the following.
# ![dataframe.PNG](attachment:dataframe.PNG)

# %% [markdown]
# Before we collect weather data from more than 500 cities, we’ll walk through how to get the weather data from Boston. First, correct the spelling for the city of Boston to get a valid URL. Then, in a new cell, add the following code and run the cell.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 72.12,
#   'feels_like': 71.38,
#   'temp_min': 68,
#   'temp_max': 75,
#   'pressure': 1007,
#   'humidity': 73},
#  'visibility': 16093,
#  'wind': {'speed': 9.17, 'deg': 180},
#  'rain': {'1h': 0.42},
#  'clouds': {'all': 90},
#  'dt': 1593293787,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1593248969,
#   'sunset': 1593303907},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# First, let's get something simple, like the country code from the JSON formatted data, which is in a nested dictionary where the first dictionary starts with sys.

# %% [markdown]
# In a new cell, let’s assign a variable to the city_weather.json() data to the variable “boston_data” and run the cell.

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %% [markdown]
# Next, using the sys key to get the corresponding value, we type boston_data['sys']in a new cell and run the cell. The output is another dictionary as shown in the following image.

# %%
boston_data["sys"]
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1593248969,
#  'sunset': 1593303907}

# %% [markdown]
# If we add the country key in brackets after the sys key, and run the cell again, ‘US’ will be returned in the output.

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %% [markdown]
# __NOTE__
# When we used boston_data["sys"], there was a key for sunrise and a key for sunset in the output. The value for these keys is the time of day in seconds in a database timestamp format.
#
# If we want to retrieve the date in the weather data, we would add the dt key to the boston_data variable like this: boston_data["dt"].

# %%
# get the date
boston_data["dt"]
# Out:
# 1593293787

# %%
# get the latitude
boston_data["coord"]["lat"]
# Out:
# 42.36

# %%
# get the max temperature
boston_data["main"]["temp_max"]
# Out:
# 75

# %%
boston_data["main"]
# Out:
# {'temp': 72.12,
#  'feels_like': 71.38,
#  'temp_min': 68,
#  'temp_max': 75,
#  'pressure': 1007,
#  'humidity': 73}

# %% [markdown]
# Using similar syntax to get the time of day, we can get the latitude, longitude, maximum temperature, humidity, percent cloudiness, and wind speed. Add the following code to a new cell and run the cell.

# %%
# define the variables, lat, lng, max_temp etc and then print the data
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 75 73 90 9.17

# %% [markdown]
# ## Convert the Date Timestamp
# The date format will appear in seconds, as we saw when we ran this code boston_data["dt"] = 1571678675
#
# This format is called Coordinated Universal Time (UTC) or Greenwich Mean Time (GMT). If we want to convert the timestamp to the International Organization for Standardization (ISO) format, or YYYY-MM-DD-HH-MM-SS, we need to use the Python datetime module.
#
# Let’s convert the date from the Boston weather data in the JSON format to the ISO format.
#
# Add the following code to a new cell in the API_practice file and run the cell.

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 6, 27, 21, 36, 27)

# %% [markdown]
# ### Convert the time date to a more readable format using .strftime()
# We can convert this datetime format to 2019-08-08 15:47:30 using the Python string format method strftime() and adding how we want the string to look inside the parentheses. In our case, we would use strftime('%Y-%m-%d %H:%M:%S').
#
# Add .strftime('%Y-%m-%d %H:%M:%S') to the end of the conversion: datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S'). Rerun the cell. The output should look like the following.

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-06-27 21:36:27'

# %% [markdown]
# Now that we know how to get all the weather data from a JSON response, we can iterate through our cities list and retrieve the data from each city.
#
# # 6.2.6 Get the City Weather Data
#
# Let’s use pseudocode to map out, at a high level, how we will get the weather data for each city for the website.
#
# We will need to do the following:
#
# 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
#     - Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.
# 6. Make an API request for each city.
# 7. Parse the JSON weather data for the following:
#     - City, country, and date
#     - Latitude and longitude
#     - Maximum temperature
#     - Humidity
#     - Cloudiness
#     - Wind speed
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %% [markdown]
# ## Import Dependencies, and Initialize an Empty List and Counters
# At the top of our code block, we are going to declare an empty list, city_data = []; add a print statement that references the beginning of the logging; and create counters for the record numbers, 1–50; and the set counter.
#
# Before adding new code to our WeatherPy file, make sure the following tasks are completed:
#
# Import your Requests Library and the weather_api_key.
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
#
# Also, import the datetime module using the following code:

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %% [markdown]
# ## Loop Through the List of Cities and Build the City URL
# Next, we need to iterate through our list of cities and begin building the URL for each city, while grouping our records in sets of 50. To do this, use for i in range(len(cities)) and the index to tell us when we get to 50. We can also retrieve the city from the cities list and add it to the city_url by using indexing, as shown in the following code:
#
# ### Looping through the cities follow the code below
#
# #### Setup counters
#
#     # Create an empty list to hold the weather data.
#     city_data = []
#     # Print the beginning of the logging.
#     print("Beginning Data Retrieval     ")
#     print("-----------------------------")
#
#     # Create counters.
#     record_count = 1
#     set_count = 1
#
# #### Loop trough cities in the list
#
# for i in range(len(cities)):
#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + "i"
#
#
# Every time we want to reference the city in our code, we need to use the indexing on the cities_list. Unfortunately, this will cause programming errors when we are building the city_url because it adds the index, not the city name, to the city_url. To fix this issue, we need to create another for loop to get the city from the cities list.
#
# Instead of using two for loops, we can use the enumerate() method as an alternative way to iterate through the list of cities and retrieve both the index, and the city from the list. The syntax for the enumerate() method is the following:
#
# for i, item in enumerate(list):
#
# Let’s use the enumerate() method to get the index of the city for logging purposes and the city for creating an endpoint URL. Add the following code below our counters.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluefield
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | barentsburg
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | alice springs
# Processing Record 8 of Set 1 | todos santos
# Processing Record 9 of Set 1 | labutta
# Processing Record 10 of Set 1 | rigaud
# Processing Record 11 of Set 1 | formosa do rio preto
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | la ronge
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | kawalu
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | penzance
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | yacopi
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | haines junction
# Processing Record 38 of Set 1 | srednekolymsk
# Processing Record 39 of Set 1 | vardo
# Processing Record 40 of Set 1 | katsuura
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | omboue
# Processing Record 43 of Set 1 | dovers
# Processing Record 44 of Set 1 | kargasok
# Processing Record 45 of Set 1 | taolanaro
# Processing Record 46 of Set 1 | nizwa
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | husavik
# Processing Record 3 of Set 2 | wadena
# Processing Record 4 of Set 2 | ugoofaaru
# Processing Record 5 of Set 2 | takob
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | mercedes
# Processing Record 11 of Set 2 | weyburn
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | naze
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | hovd
# Processing Record 16 of Set 2 | palmas
# Processing Record 17 of Set 2 | hihifo
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | necochea
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | berdigestyakh
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | yatou
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | ternate
# Processing Record 29 of Set 2 | humaita
# Processing Record 30 of Set 2 | belushya guba
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | vao
# Processing Record 6 of Set 4 | saint george
# Processing Record 7 of Set 4 | half moon bay
# Processing Record 8 of Set 4 | samusu
# Processing Record 9 of Set 4 | gat
# Processing Record 10 of Set 4 | bargal
# Processing Record 11 of Set 4 | deputatskiy
# Processing Record 12 of Set 4 | hobyo
# Processing Record 13 of Set 4 | shihezi
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | avera
# Processing Record 16 of Set 4 | porto novo
# Processing Record 17 of Set 4 | tlaxco
# Processing Record 18 of Set 4 | vanimo
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | pozo colorado
# Processing Record 21 of Set 4 | delta del tigre
# Processing Record 22 of Set 4 | kloulklubed
# Processing Record 23 of Set 4 | deniliquin
# Processing Record 24 of Set 4 | marystown
# Processing Record 25 of Set 4 | niigata
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | vryburg
# Processing Record 28 of Set 4 | airai
# Processing Record 29 of Set 4 | florencia
# Processing Record 30 of Set 4 | temaraia
# Processing Record 31 of Set 4 | grand gaube
# Processing Record 32 of Set 4 | salalah
# Processing Record 33 of Set 4 | garowe
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | basudebpur
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | hasaki
# Processing Record 38 of Set 4 | ferkessedougou
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | wulanhaote
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | madera
# Processing Record 43 of Set 4 | las vegas
# Processing Record 44 of Set 4 | kilakarai
# Processing Record 45 of Set 4 | alta floresta
# Processing Record 46 of Set 4 | ponta delgada
# Processing Record 47 of Set 4 | saint-francois
# Processing Record 48 of Set 4 | port hardy
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | oktyabrskiy
# Processing Record 1 of Set 5 | qaanaaq
# Processing Record 2 of Set 5 | asyut
# Processing Record 3 of Set 5 | belgrade
# Processing Record 4 of Set 5 | tuktoyaktuk
# Processing Record 5 of Set 5 | progreso
# Processing Record 6 of Set 5 | winnemucca
# Processing Record 7 of Set 5 | kerman
# Processing Record 8 of Set 5 | nantucket
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | ngukurr
# Processing Record 12 of Set 5 | lerwick
# Processing Record 13 of Set 5 | vila do maio
# Processing Record 14 of Set 5 | saleaula
# Processing Record 15 of Set 5 | mbaiki
# Processing Record 16 of Set 5 | owando
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | gogrial
# Processing Record 19 of Set 5 | yerbogachen
# Processing Record 20 of Set 5 | quatre cocos
# Processing Record 21 of Set 5 | pitimbu
# Processing Record 22 of Set 5 | rio gallegos
# Processing Record 23 of Set 5 | labuhan
# Processing Record 24 of Set 5 | souillac
# Processing Record 25 of Set 5 | udachnyy
# Processing Record 26 of Set 5 | te anau
# Processing Record 27 of Set 5 | lima
# Processing Record 28 of Set 5 | san policarpo
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | chalus
# Processing Record 31 of Set 5 | savannah bight
# Processing Record 32 of Set 5 | orlik
# Processing Record 33 of Set 5 | vila velha
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | mount gambier
# Processing Record 36 of Set 5 | palabuhanratu
# Processing Record 37 of Set 5 | adrar
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | acarau
# Processing Record 40 of Set 5 | nouadhibou
# Processing Record 41 of Set 5 | marcona
# Processing Record 42 of Set 5 | catuday
# Processing Record 43 of Set 5 | bella vista
# Processing Record 44 of Set 5 | buseresere
# Processing Record 45 of Set 5 | broome
# Processing Record 46 of Set 5 | sao joao da barra
# Processing Record 47 of Set 5 | fairbanks
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | channel-port aux basques
# Processing Record 50 of Set 5 | wuda
# Processing Record 1 of Set 6 | guilin
# Processing Record 2 of Set 6 | saint-pierre
# Processing Record 3 of Set 6 | college
# Processing Record 4 of Set 6 | dongsheng
# Processing Record 5 of Set 6 | richards bay
# Processing Record 6 of Set 6 | garmsar
# Processing Record 7 of Set 6 | sao felix do xingu
# Processing Record 8 of Set 6 | austin
# Processing Record 9 of Set 6 | ishigaki
# Processing Record 10 of Set 6 | tsihombe
# Processing Record 11 of Set 6 | sentyabrskiy
# Processing Record 12 of Set 6 | isangel
# Processing Record 13 of Set 6 | muriti
# Processing Record 14 of Set 6 | illoqqortoormiut
# Processing Record 15 of Set 6 | tabou
# Processing Record 16 of Set 6 | dubai
# Processing Record 17 of Set 6 | mayo
# Processing Record 18 of Set 6 | mahebourg
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | saldanha
# Processing Record 21 of Set 6 | kyzyl-suu
# Processing Record 22 of Set 6 | saint-philippe
# Processing Record 23 of Set 6 | yellowknife
# Processing Record 24 of Set 6 | moerai
# Processing Record 25 of Set 6 | brae
# Processing Record 26 of Set 6 | hamilton
# Processing Record 27 of Set 6 | west lorne
# Processing Record 28 of Set 6 | najran
# Processing Record 29 of Set 6 | faanui
# Processing Record 30 of Set 6 | adana
# Processing Record 31 of Set 6 | tual
# Processing Record 32 of Set 6 | dunedin
# Processing Record 33 of Set 6 | kranea elassonos
# Processing Record 34 of Set 6 | chicama
# Processing Record 35 of Set 6 | soe
# Processing Record 36 of Set 6 | mount isa
# Processing Record 37 of Set 6 | kenai
# Processing Record 38 of Set 6 | muriwai beach
# Processing Record 39 of Set 6 | okhotsk
# Processing Record 40 of Set 6 | mayya
# Processing Record 41 of Set 6 | scottsbluff
# Processing Record 42 of Set 6 | birao
# Processing Record 43 of Set 6 | nalut
# Processing Record 44 of Set 6 | edson
# Processing Record 45 of Set 6 | geraldton
# Processing Record 46 of Set 6 | barawe
# Processing Record 47 of Set 6 | grindavik
# Processing Record 48 of Set 6 | arman
# Processing Record 49 of Set 6 | ciudad guayana
# Processing Record 50 of Set 6 | tete
# Processing Record 1 of Set 7 | santa isabel do rio negro
# Processing Record 2 of Set 7 | sisimiut
# Processing Record 3 of Set 7 | ketchikan
# Processing Record 4 of Set 7 | kuruman
# Processing Record 5 of Set 7 | xiaoweizhai
# Processing Record 6 of Set 7 | togur
# Processing Record 7 of Set 7 | severo-yeniseyskiy
# Processing Record 8 of Set 7 | yulara
# Processing Record 9 of Set 7 | ewa beach
# Processing Record 10 of Set 7 | juneau
# Processing Record 11 of Set 7 | moctezuma
# Processing Record 12 of Set 7 | asenovgrad
# Processing Record 13 of Set 7 | sola
# Processing Record 14 of Set 7 | urcos
# Processing Record 15 of Set 7 | flin flon
# Processing Record 16 of Set 7 | broken hill
# Processing Record 17 of Set 7 | nome
# Processing Record 18 of Set 7 | ahipara
# Processing Record 19 of Set 7 | lazaro cardenas
# Processing Record 20 of Set 7 | medicine hat
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | yar-sale
# Processing Record 23 of Set 7 | fukue
# Processing Record 24 of Set 7 | pierre
# Processing Record 25 of Set 7 | sabang
# Processing Record 26 of Set 7 | belyy yar
# Processing Record 27 of Set 7 | chapais
# Processing Record 28 of Set 7 | rocha
# Processing Record 29 of Set 7 | cabra
# Processing Record 30 of Set 7 | krasnoborsk
# Processing Record 31 of Set 7 | inongo
# Processing Record 32 of Set 7 | lolua
# Processing Record 33 of Set 7 | tateyama
# Processing Record 34 of Set 7 | paamiut
# Processing Record 35 of Set 7 | ambulu
# Processing Record 36 of Set 7 | saint-augustin
# Processing Record 37 of Set 7 | mezen
# Processing Record 38 of Set 7 | grand river south east
# Processing Record 39 of Set 7 | pueblo bello
# Processing Record 40 of Set 7 | rolim de moura
# Processing Record 41 of Set 7 | nisia floresta
# Processing Record 42 of Set 7 | bilma
# Processing Record 43 of Set 7 | mackenzie
# Processing Record 44 of Set 7 | wattegama
# Processing Record 45 of Set 7 | taoudenni
# Processing Record 46 of Set 7 | zhigansk
# Processing Record 47 of Set 7 | cabo san lucas
# Processing Record 48 of Set 7 | luderitz
# Processing Record 49 of Set 7 | port moresby
# Processing Record 50 of Set 7 | rafai
# Processing Record 1 of Set 8 | xiongzhou
# Processing Record 2 of Set 8 | carlos antonio lopez
# Processing Record 3 of Set 8 | arsikere
# Processing Record 4 of Set 8 | belmonte
# Processing Record 5 of Set 8 | palo alto
# Processing Record 6 of Set 8 | azuaga
# Processing Record 7 of Set 8 | guarda
# Processing Record 8 of Set 8 | stornoway
# Processing Record 9 of Set 8 | codrington
# Processing Record 10 of Set 8 | gamba
# Processing Record 11 of Set 8 | klyuchi
# Processing Record 12 of Set 8 | dembi dolo
# Processing Record 13 of Set 8 | wanning
# Processing Record 14 of Set 8 | pacific grove
# Processing Record 15 of Set 8 | anadyr
# Processing Record 16 of Set 8 | kruisfontein
# Processing Record 17 of Set 8 | cayenne
# Processing Record 18 of Set 8 | ukiah
# Processing Record 19 of Set 8 | kerns
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | sangar
# Processing Record 22 of Set 8 | ongandjera
# Processing Record 23 of Set 8 | palmerston
# Processing Record 24 of Set 8 | santa isabel
# Processing Record 25 of Set 8 | vostok
# Processing Record 26 of Set 8 | port macquarie
# Processing Record 27 of Set 8 | ilulissat
# Processing Record 28 of Set 8 | darhan
# Processing Record 29 of Set 8 | sioux lookout
# Processing Record 30 of Set 8 | safwah
# Processing Record 31 of Set 8 | alpena
# Processing Record 32 of Set 8 | sur
# Processing Record 33 of Set 8 | hervey bay
# Processing Record 34 of Set 8 | mys shmidta
# Processing Record 35 of Set 8 | huarmey
# Processing Record 36 of Set 8 | nizhneyansk
# Processing Record 37 of Set 8 | caravelas
# Processing Record 38 of Set 8 | camopi
# Processing Record 39 of Set 8 | falealupo
# Processing Record 40 of Set 8 | socorro
# Processing Record 41 of Set 8 | nelson bay
# Processing Record 42 of Set 8 | yumen
# Processing Record 43 of Set 8 | chakia
# Processing Record 44 of Set 8 | prince rupert
# Processing Record 45 of Set 8 | mayumba
# Processing Record 46 of Set 8 | punta cardon
# Processing Record 47 of Set 8 | divnoye
# Processing Record 48 of Set 8 | jujuy
# Processing Record 49 of Set 8 | sale
# Processing Record 50 of Set 8 | hofn
# Processing Record 1 of Set 9 | manjeshwar
# Processing Record 2 of Set 9 | lakes entrance
# Processing Record 3 of Set 9 | katangli
# Processing Record 4 of Set 9 | yunjinghong
# Processing Record 5 of Set 9 | kahului
# Processing Record 6 of Set 9 | poum
# Processing Record 7 of Set 9 | sakakah
# Processing Record 8 of Set 9 | cherskiy
# Processing Record 9 of Set 9 | redmond
# Processing Record 10 of Set 9 | murchison
# Processing Record 11 of Set 9 | ambovombe
# Processing Record 12 of Set 9 | taksimo
# Processing Record 13 of Set 9 | dakar
# Processing Record 14 of Set 9 | marathon
# Processing Record 15 of Set 9 | srednebelaya
# Processing Record 16 of Set 9 | wabash
# Processing Record 17 of Set 9 | vysokogornyy
# Processing Record 18 of Set 9 | karratha
# Processing Record 19 of Set 9 | rangpo
# Processing Record 20 of Set 9 | jacareacanga
# Processing Record 21 of Set 9 | mrirt
# Processing Record 22 of Set 9 | saint-joseph
# Processing Record 23 of Set 9 | borogontsy
# Processing Record 24 of Set 9 | anori
# Processing Record 25 of Set 9 | sergeyevka
# Processing Record 26 of Set 9 | goderich
# Processing Record 27 of Set 9 | tamandare
# Processing Record 28 of Set 9 | muli
# Processing Record 29 of Set 9 | trelew
# Processing Record 30 of Set 9 | santa margherita ligure
# Processing Record 31 of Set 9 | chingola
# Processing Record 32 of Set 9 | lisala
# Processing Record 33 of Set 9 | ust-kalmanka
# Processing Record 34 of Set 9 | vanderhoof
# Processing Record 35 of Set 9 | port blair
# Processing Record 36 of Set 9 | huai yot
# Processing Record 37 of Set 9 | boguchany
# Processing Record 38 of Set 9 | haldensleben
# Processing Record 39 of Set 9 | gizo
# Processing Record 40 of Set 9 | puerto cabezas
# Processing Record 41 of Set 9 | lasa
# Processing Record 42 of Set 9 | roald
# Processing Record 43 of Set 9 | alberton
# Processing Record 44 of Set 9 | san juan
# Processing Record 45 of Set 9 | baoshan
# Processing Record 46 of Set 9 | kuito
# Processing Record 47 of Set 9 | fort frances
# Processing Record 48 of Set 9 | muravlenko
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | yeppoon
# Processing Record 1 of Set 10 | bronnoysund
# Processing Record 2 of Set 10 | pemba
# Processing Record 3 of Set 10 | puerto escondido
# Processing Record 4 of Set 10 | peniche
# Processing Record 5 of Set 10 | ostrovnoy
# Processing Record 6 of Set 10 | higuey
# Processing Record 7 of Set 10 | torbat-e jam
# Processing Record 8 of Set 10 | nauchnyy gorodok
# Processing Record 9 of Set 10 | mehamn
# Processing Record 10 of Set 10 | nizhnevartovsk
# Processing Record 11 of Set 10 | pemberton
# Processing Record 12 of Set 10 | umzimvubu
# Processing Record 13 of Set 10 | skjervoy
# Processing Record 14 of Set 10 | sterling
# Processing Record 15 of Set 10 | provideniya
# Processing Record 16 of Set 10 | mata
# Processing Record 17 of Set 10 | kilim
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | bereznik
# Processing Record 20 of Set 10 | xuddur
# Processing Record 21 of Set 10 | sobolevo
# Processing Record 22 of Set 10 | newport
# Processing Record 23 of Set 10 | deville-les-rouen
# Processing Record 24 of Set 10 | noumea
# Processing Record 25 of Set 10 | surt
# Processing Record 26 of Set 10 | capreol
# Processing Record 27 of Set 10 | emerald
# Processing Record 28 of Set 10 | tigil
# Processing Record 29 of Set 10 | mier
# Processing Record 30 of Set 10 | ulyanovo
# Processing Record 31 of Set 10 | road town
# Processing Record 32 of Set 10 | kutum
# Processing Record 33 of Set 10 | madimba
# Processing Record 34 of Set 10 | kibaya
# Processing Record 35 of Set 10 | hualmay
# Processing Record 36 of Set 10 | kautokeino
# Processing Record 37 of Set 10 | coquimbo
# Processing Record 38 of Set 10 | shirokiy
# Processing Record 39 of Set 10 | tres arroyos
# Processing Record 40 of Set 10 | clyde river
# Processing Record 41 of Set 10 | attawapiskat
# Processing Record 42 of Set 10 | hami
# Processing Record 43 of Set 10 | libreville
# Processing Record 44 of Set 10 | aykhal
# Processing Record 45 of Set 10 | manono
# Processing Record 46 of Set 10 | formosa
# Processing Record 47 of Set 10 | kununurra
# Processing Record 48 of Set 10 | treinta y tres
# Processing Record 49 of Set 10 | ossora
# Processing Record 50 of Set 10 | mastic beach
# Processing Record 1 of Set 11 | zacatepec
# Processing Record 2 of Set 11 | bonfim
# Processing Record 3 of Set 11 | korla
# Processing Record 4 of Set 11 | sydney
# Processing Record 5 of Set 11 | mocuba
# Processing Record 6 of Set 11 | camacari
# Processing Record 7 of Set 11 | znamenskoye
# Processing Record 8 of Set 11 | ofaqim
# Processing Record 9 of Set 11 | sinnamary
# Processing Record 10 of Set 11 | douglas
# Processing Record 11 of Set 11 | guerrero negro
# Processing Record 12 of Set 11 | castelo branco
# Processing Record 13 of Set 11 | krasnoselkup
# Processing Record 14 of Set 11 | rafaela
# Processing Record 15 of Set 11 | tulun
# Processing Record 16 of Set 11 | alsfeld
# Processing Record 17 of Set 11 | springbok
# Processing Record 18 of Set 11 | muros
# Processing Record 19 of Set 11 | lithgow
# Processing Record 20 of Set 11 | lesozavodsk
# Processing Record 21 of Set 11 | coihaique
# Processing Record 22 of Set 11 | issoire
# Processing Record 23 of Set 11 | makakilo city
# Processing Record 24 of Set 11 | vila
# Processing Record 25 of Set 11 | tomakomai
# Processing Record 26 of Set 11 | grenaa
# Processing Record 27 of Set 11 | pangai
# Processing Record 28 of Set 11 | itaqui
# Processing Record 29 of Set 11 | maloshuyka
# Processing Record 30 of Set 11 | tilichiki
# Processing Record 31 of Set 11 | arlit
# Processing Record 32 of Set 11 | high level
# Processing Record 33 of Set 11 | dolores
# Processing Record 34 of Set 11 | namatanai
# Processing Record 35 of Set 11 | lircay
# Processing Record 36 of Set 11 | oxford
# Processing Record 37 of Set 11 | sault sainte marie
# Processing Record 38 of Set 11 | isiro
# Processing Record 39 of Set 11 | malaya serdoba
# Processing Record 40 of Set 11 | dingle
# Processing Record 41 of Set 11 | ekhabi
# Processing Record 42 of Set 11 | tessalit
# Processing Record 43 of Set 11 | alamosa
# Processing Record 44 of Set 11 | olafsvik
# Processing Record 45 of Set 11 | paranaiba
# Processing Record 46 of Set 11 | north battleford
# Processing Record 47 of Set 11 | praia da vitoria
# Processing Record 48 of Set 11 | kharp
# Processing Record 49 of Set 11 | esso
# Processing Record 50 of Set 11 | muroto
# Processing Record 1 of Set 12 | kirakira
# Processing Record 2 of Set 12 | santa fe
# Processing Record 3 of Set 12 | lanigan
# Processing Record 4 of Set 12 | hunza
# Processing Record 5 of Set 12 | nuuk
# Processing Record 6 of Set 12 | amatlan
# Processing Record 7 of Set 12 | aranos
# Processing Record 8 of Set 12 | hanzhong
# Processing Record 9 of Set 12 | zaysan
# Processing Record 10 of Set 12 | uporovo
# Processing Record 11 of Set 12 | asau
# Processing Record 12 of Set 12 | mackay
# Processing Record 13 of Set 12 | dergachi
# Processing Record 14 of Set 12 | grants
# Processing Record 15 of Set 12 | kakonko
# Processing Record 16 of Set 12 | fort nelson
# Processing Record 17 of Set 12 | bansko
# Processing Record 18 of Set 12 | rondonopolis
# Processing Record 19 of Set 12 | seoul
# Processing Record 20 of Set 12 | beidao
# Processing Record 21 of Set 12 | preobrazheniye
# Processing Record 22 of Set 12 | felanitx
# Processing Record 23 of Set 12 | alquizar
# Processing Record 24 of Set 12 | manadhoo
# Processing Record 25 of Set 12 | boende
# Processing Record 26 of Set 12 | hakvik
# Processing Record 27 of Set 12 | virginia beach
# Processing Record 28 of Set 12 | koshurnikovo
# Processing Record 29 of Set 12 | trat
# Processing Record 30 of Set 12 | cabo rojo
# Processing Record 31 of Set 12 | meridian
# Processing Record 32 of Set 12 | chinsali
# Processing Record 33 of Set 12 | bulaevo
# Processing Record 34 of Set 12 | utiroa
# Processing Record 35 of Set 12 | north bend
# Processing Record 36 of Set 12 | jonuta
# Processing Record 37 of Set 12 | igrim
# Processing Record 38 of Set 12 | chifeng
# Processing Record 39 of Set 12 | bunbury
# Processing Record 40 of Set 12 | bhuj
# Processing Record 41 of Set 12 | ouesso
# Processing Record 42 of Set 12 | pontianak
# Processing Record 43 of Set 12 | gejiu
# Processing Record 44 of Set 12 | majene
# Processing Record 45 of Set 12 | nemuro
# Processing Record 46 of Set 12 | campbell river
# Processing Record 47 of Set 12 | kamaishi
# Processing Record 48 of Set 12 | maniitsoq
# Processing Record 49 of Set 12 | dalbandin
# Processing Record 50 of Set 12 | opuwo
# Processing Record 1 of Set 13 | beaverlodge
# Processing Record 2 of Set 13 | camocim
# Processing Record 3 of Set 13 | cap malheureux
# Processing Record 4 of Set 13 | margate
# Processing Record 5 of Set 13 | banjarmasin

# %% [markdown]
# Let’s break down the code so we understand fully before continuing:
#
# - We create the for loop with the enumerate() method and reference the index and the city in the list.
# - In the conditional statement, we check if the remainder of the index divided by 50 is equal to 0 and if the index is greater than or equal to 50. If the statement is true, then the set_count and the record_count are equal to 1.
# - Inside the conditional statement, we create the URL endpoint for each city, as before. However, we are removing the blank spaces in the city name and concatenating the city name with, city.replace(" ","+"). This will find the corresponding weather data for the city instead of finding the weather data for the first part of the city name.
# Compare the URLs for Cabo (Links to an external site.) and Cabo San Lucas (Links to an external site.).
# - Also, we add a print statement that tells us the record count and set count, and the city that is being processed.
# - Then we add one to the record count before the next city is processed.
# Next, we will retrieve the data from the JSON weather response for each city.
#
# __NOTE__
# When retrieving data from an API, or even when scraping a webpage, make sure there is data to parse. If not, the script might stop at that moment and not finish getting all the data we need.

# %% [markdown]
# ## Handle API Request Errors with try-except Blocks
#
# We have handled request errors for getting the response from a valid city with an API call using conditional statements. Now we’ll learn how to handle errors while parsing weather data from a JSON file.
#
# We’ll add a try-except block to our code to prevent the API request from stopping prematurely if the city_weather request isn't a valid response. If the request isn’t valid, the code will not find the first item requested, which is the dictionary "coord" with the code city_lat = city_weather["coord"]["lat"], and skip the city and continue to run.
#
# The try-except block has similar syntax and structure as the if-else statement. The basic format is as follows:
#
#     try:
#       Do something
#     except:
#       print("An exception occurred")
#
# We can add a try-except block to our code and, below the try block, we will parse the data from the JSON file and add the data to the cities list.
#
# Let’s add a try block. Then, below the try block, do the following:
#
# 1. Parse the JSON file.
# 2. Assign variables for each piece of data we need.
# 3. Add the data to the cities list in a dictionary format.
# 4. Add the following code after record_count += 1.

# %%
# Run an API request for each of the cities.
try:
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
    # Parse out the needed data.
    city_lat = city_weather["coord"]["lat"]
    city_lng = city_weather["coord"]["lon"]
    city_max_temp = city_weather["main"]["temp_max"]
    city_humidity = city_weather["main"]["humidity"]
    city_clouds = city_weather["clouds"]["all"]
    city_wind = city_weather["wind"]["speed"]
    city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
    city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
    city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 2

# %% [markdown]
# # 6.2.7 Create a DataFrame of City Weather Data
#
# Our next steps will entail converting the array of dictionaries to a DataFrame, ensuring the columns are in the correct order, and exporting the DataFrame to a comma-separated (CSV) file.
#
# REWIND
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# In a new cell, add the following code to convert the array of dictionaries to a Pandas DataFrame and run the cell.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City   Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Banjarmasin -3.32  114.59     71.51        97         100        1.14
# 1  Banjarmasin -3.32  114.59     71.51        97         100        1.14
#
#   Country                 Date
# 0      ID  2020-06-27 21:40:22
# 1      ID  2020-06-27 21:40:22

# %% [markdown]
# ## 6.4.1 Use Linear Regression to Find the Relationship Between Variables
#
# Linear regression is used to find a relationship between a dependent variable and one or more independent variables. The trick is to find something (a dependent variable) that depends on something else (the independent variable) and plot that relationship.
#
# For example, let’s say we wanted to understand how weather affects ice cream sales. We would model the linear regression between temperature (the independent variable) and ice cream sales (the dependent variable). Our hypothesis about the relationship would be that as temperatures rise, as they do in summer, more ice cream is sold. We will learn more hypothesis testing and building models in later modules.
#
# For your project, you’ve already been working with independent and dependent variables. We have enough data to test relationships by creating scatter plots as we’ve done for each weather parameter vs. latitude. Plotting the data is the first step in determining if there might be an association between the two variables. For our scatter plots, the independent variable is the latitude, plotted on the x-axis, as its value is fixed. When we change the latitude, temperature changes, making it the dependent variable.
#
# Independent variable: the variable changed by the analyst to observe how it affects the dependent variable
#
# Dependent variable: the variable tested by the analyst to observe how it is affected by the independent variable

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %% [markdown]
# In the code to perform linear regression, the linregress function takes only two arguments, the x- and y-axes data (lats and temps) in the form of arrays. And it returns the following:
#
# - Slope of the regression line as slope
# - y-intercept as intercept
# - Correlation coefficient as r_value
# - p-value as p_value
# - Standard error as std_err
#
# The slope, intercept, r_value, p_value, and std_err are always returned when we run the linregress function. If you don’t want to calculate one of these values but do not add it inside the parentheses, you’ll get a ValueError: too many values to unpack.
#
# To prevent this error, add a comma and underscore for each value you don’t want to calculate.
#
# For instance, if you don’t want to print out the p-value and the standard error, write your function as (slope, intercept, r_value, _, _) = linregress(x, y).
#
# In statistics, the p-value is used to determine significance of results. In most cases, data scientists like to use a significance level of 0.05, which means:
#
# A linear regression with a p-value > 0.05 is not statistically significant.
#
# A linear regression with a p-value < 0.05 is statistically significant.
#
# P-values can also be used to justify rejecting a null hypothesis. We will discuss p-values and hypothesis testing in more detail later in the course.
#
# Now we can calculate the ideal temperatures (y-values) using the slope and intercept from the equation of the regression line. To do this, perform list comprehension on the latitudes by multiplying each latitude by the slope and adding the intercept.
#
# Add the following code in a new cell and run the cell.

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %% [markdown]
# Let’s review what this code does:
#
# - We plot the latitudes and temperatures on a scatter plot.
# - We create a line plot of our regression line with the ideal temperatures.
# - We annotate the line plot by adding the equation of our regression line, where the x-axis is 10 and the y-axis is 40, and specify the font and color.
# - We create x- and y-axes labels.
#
# Now let’s run the cell and plot our data.

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept. 
regress_values = x_values * slope + intercept

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-383beabd49bf> in <module>
#       1 # Perform linear regression.
# ----> 2 (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
#       3
#       4 # Calculate the regression line "y values" from the slope and intercept.
#       5 regress_values = x_values * slope + intercept
#
# NameError: name 'x_values' is not defined
