# %%
# Import the dependencies.
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# PERFORM AN API CALL WITH OPENWEATHER.ORG
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # print(city_weather) $$ you can check anywhere to see if if it's retrieving data
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["main"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        try:
            city_rainfall = city_weather["rain"]["1h"]
        except KeyError:
            city_rainfall = 0
        try:
            city_snowfall = city_weather["snow"]["1h"]
        except KeyError:
            city_snowfall = 0        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Current Weather": city_weather_description,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Rain":city_rainfall,
                          "Snow":city_snowfall})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(city_weather)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | tiarei
# Processing Record 3 of Set 1 | lalibela
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | touros
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | namatanai
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | gat
# Processing Record 17 of Set 1 | erenhot
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | alta floresta
# Processing Record 21 of Set 1 | parana
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 1 | odiongan
# Processing Record 27 of Set 1 | fort nelson
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | broken hill
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | katsuura
# Processing Record 33 of Set 1 | port blair
# Processing Record 34 of Set 1 | bose
# Processing Record 35 of Set 1 | north bend
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | saintes
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | bilibino
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | kirakira
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | uralskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 2 | faanui
# Processing Record 3 of Set 2 | vyara
# Processing Record 4 of Set 2 | yarada
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | otavi
# Processing Record 7 of Set 2 | itoman
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | tilichiki
# Processing Record 10 of Set 2 | ivanteyevka
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 2 | mogadishu
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | coquimbo
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | ostrovnoy
# Processing Record 19 of Set 2 | traverse city
# Processing Record 20 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | balkhash
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | sioux lookout
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | deputatskiy
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | arosa
# Processing Record 29 of Set 2 | hede
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | mechetinskaya
# Processing Record 32 of Set 2 | tombouctou
# Processing Record 33 of Set 2 | margate
# Processing Record 34 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 2 | luena
# Processing Record 36 of Set 2 | roma
# Processing Record 37 of Set 2 | seoul
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | tamandare
# Processing Record 40 of Set 2 | glendive
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | daru
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | grand-santi
# Processing Record 50 of Set 2 | umm kaddadah
# Processing Record 1 of Set 3 | kochubey
# Processing Record 2 of Set 3 | erzin
# Processing Record 3 of Set 3 | davila
# Processing Record 4 of Set 3 | hithadhoo
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | aklavik
# Processing Record 7 of Set 3 | srednekolymsk
# Processing Record 8 of Set 3 | vostok
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | yakeshi
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | bandarbeyla
# Processing Record 13 of Set 3 | bonthe
# Processing Record 14 of Set 3 | slave lake
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | severo-kurilsk
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | antofagasta
# Processing Record 22 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | kiama
# Processing Record 27 of Set 3 | lasa
# Processing Record 28 of Set 3 | youghal
# Processing Record 29 of Set 3 | wewak
# Processing Record 30 of Set 3 | marki
# Processing Record 31 of Set 3 | mayumba
# Processing Record 32 of Set 3 | jati
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | seki
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | bubaque
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | ucluelet
# Processing Record 39 of Set 3 | neiafu
# Processing Record 40 of Set 3 | agadir
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | dalvik
# Processing Record 43 of Set 3 | ponta do sol
# Processing Record 44 of Set 3 | rocha
# Processing Record 45 of Set 3 | ransang
# Processing Record 46 of Set 3 | leningradskiy
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | iskandar
# Processing Record 49 of Set 3 | mahibadhoo
# Processing Record 50 of Set 3 | les cayes
# Processing Record 1 of Set 4 | naushki
# Processing Record 2 of Set 4 | bud
# Processing Record 3 of Set 4 | maniitsoq
# Processing Record 4 of Set 4 | tanda
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | poum
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | miri
# Processing Record 9 of Set 4 | znamenskoye
# Processing Record 10 of Set 4 | korla
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | vuktyl
# Processing Record 13 of Set 4 | tautira
# Processing Record 14 of Set 4 | kankon
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 4 | morondava
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | varnamo
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | bilma
# Processing Record 25 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 26 of Set 4 | novoagansk
# Processing Record 27 of Set 4 | bathurst
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | nara
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | katherine
# Processing Record 32 of Set 4 | ahipara
# Processing Record 33 of Set 4 | yerbogachen
# Processing Record 34 of Set 4 | iroquois falls
# Processing Record 35 of Set 4 | mar del plata
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | oga
# Processing Record 39 of Set 4 | san policarpo
# Processing Record 40 of Set 4 | zhigansk
# Processing Record 41 of Set 4 | kismayo
# Processing Record 42 of Set 4 | luanda
# Processing Record 43 of Set 4 | komsomolskiy
# Processing Record 44 of Set 4 | georgetown
# Processing Record 45 of Set 4 | tiksi
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | raahe
# Processing Record 48 of Set 4 | vredendal
# Processing Record 49 of Set 4 | coos bay
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | castanos
# Processing Record 2 of Set 5 | dolores
# Processing Record 3 of Set 5 | kuva
# City not found. Skipping...
# Processing Record 4 of Set 5 | celestun
# Processing Record 5 of Set 5 | challapata
# Processing Record 6 of Set 5 | derzhavinsk
# Processing Record 7 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 5 | iralaya
# Processing Record 9 of Set 5 | phalaborwa
# Processing Record 10 of Set 5 | kaitangata
# Processing Record 11 of Set 5 | yining
# Processing Record 12 of Set 5 | autazes
# Processing Record 13 of Set 5 | iskateley
# Processing Record 14 of Set 5 | sitka
# Processing Record 15 of Set 5 | fayaoue
# Processing Record 16 of Set 5 | ancud
# Processing Record 17 of Set 5 | araouane
# Processing Record 18 of Set 5 | nova olimpia
# Processing Record 19 of Set 5 | collie
# Processing Record 20 of Set 5 | brae
# Processing Record 21 of Set 5 | tateyama
# Processing Record 22 of Set 5 | haines junction
# Processing Record 23 of Set 5 | bambous virieux
# Processing Record 24 of Set 5 | fez
# Processing Record 25 of Set 5 | broome
# Processing Record 26 of Set 5 | khapa
# Processing Record 27 of Set 5 | tezu
# Processing Record 28 of Set 5 | inuvik
# Processing Record 29 of Set 5 | ossora
# Processing Record 30 of Set 5 | tucupita
# Processing Record 31 of Set 5 | buala
# Processing Record 32 of Set 5 | mochudi
# Processing Record 33 of Set 5 | tarrafal
# Processing Record 34 of Set 5 | torres
# Processing Record 35 of Set 5 | westport
# Processing Record 36 of Set 5 | constitucion
# Processing Record 37 of Set 5 | zeya
# Processing Record 38 of Set 5 | mangan
# Processing Record 39 of Set 5 | kota tinggi
# Processing Record 40 of Set 5 | burnie
# Processing Record 41 of Set 5 | kaifeng
# Processing Record 42 of Set 5 | dongsheng
# Processing Record 43 of Set 5 | nhulunbuy
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | praia da vitoria
# Processing Record 47 of Set 5 | paengaroa
# Processing Record 48 of Set 5 | mayo
# Processing Record 49 of Set 5 | nikolskoye
# Processing Record 50 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 1 of Set 6 | morehead
# Processing Record 2 of Set 6 | umm lajj
# Processing Record 3 of Set 6 | pouebo
# Processing Record 4 of Set 6 | hofn
# Processing Record 5 of Set 6 | kodiak
# Processing Record 6 of Set 6 | the pas
# Processing Record 7 of Set 6 | chokurdakh
# Processing Record 8 of Set 6 | alyangula
# Processing Record 9 of Set 6 | port hardy
# Processing Record 10 of Set 6 | yumen
# Processing Record 11 of Set 6 | la ronge
# Processing Record 12 of Set 6 | xining
# Processing Record 13 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 14 of Set 6 | lumphat
# Processing Record 15 of Set 6 | mujiayingzi
# Processing Record 16 of Set 6 | limbe
# Processing Record 17 of Set 6 | ifanadiana
# Processing Record 18 of Set 6 | paamiut
# Processing Record 19 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 6 | veraval
# Processing Record 21 of Set 6 | zhezkazgan
# Processing Record 22 of Set 6 | gigmoto
# Processing Record 23 of Set 6 | flinders
# Processing Record 24 of Set 6 | asau
# Processing Record 25 of Set 6 | marawi
# Processing Record 26 of Set 6 | veydelevka
# Processing Record 27 of Set 6 | aksarka
# Processing Record 28 of Set 6 | presidencia roque saenz pena
# Processing Record 29 of Set 6 | banda aceh
# Processing Record 30 of Set 6 | odweyne
# Processing Record 31 of Set 6 | traralgon
# Processing Record 32 of Set 6 | karratha
# Processing Record 33 of Set 6 | sao miguel do araguaia
# Processing Record 34 of Set 6 | hami
# Processing Record 35 of Set 6 | salinopolis
# Processing Record 36 of Set 6 | alappuzha
# Processing Record 37 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 6 | praya
# Processing Record 39 of Set 6 | baruun-urt
# Processing Record 40 of Set 6 | grindavik
# Processing Record 41 of Set 6 | kem
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | angoche
# Processing Record 44 of Set 6 | vanavara
# Processing Record 45 of Set 6 | khuzdar
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | kysyl-syr
# Processing Record 48 of Set 6 | pacific grove
# Processing Record 49 of Set 6 | beroroha
# Processing Record 50 of Set 6 | san juan
# Processing Record 1 of Set 7 | alice springs
# Processing Record 2 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 3 of Set 7 | bay roberts
# Processing Record 4 of Set 7 | mitzic
# Processing Record 5 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 7 | geraldton
# Processing Record 7 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 8 of Set 7 | abatskoye
# Processing Record 9 of Set 7 | beringovskiy
# Processing Record 10 of Set 7 | sinnamary
# Processing Record 11 of Set 7 | esperance
# Processing Record 12 of Set 7 | walvis bay
# Processing Record 13 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 7 | albion
# Processing Record 15 of Set 7 | tauranga
# Processing Record 16 of Set 7 | porto novo
# Processing Record 17 of Set 7 | ulaangom
# Processing Record 18 of Set 7 | bereda
# Processing Record 19 of Set 7 | akyab
# Processing Record 20 of Set 7 | reserva
# Processing Record 21 of Set 7 | arraial do cabo
# Processing Record 22 of Set 7 | bosaso
# Processing Record 23 of Set 7 | nemuro
# Processing Record 24 of Set 7 | louis trichardt
# Processing Record 25 of Set 7 | chapais
# Processing Record 26 of Set 7 | quatre cocos
# Processing Record 27 of Set 7 | tyulyachi
# Processing Record 28 of Set 7 | galveston
# Processing Record 29 of Set 7 | pontianak
# Processing Record 30 of Set 7 | richards bay
# Processing Record 31 of Set 7 | lincoln
# Processing Record 32 of Set 7 | huarmey
# Processing Record 33 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | vao
# Processing Record 36 of Set 7 | barcelos
# Processing Record 37 of Set 7 | kalaleh
# Processing Record 38 of Set 7 | half moon bay
# Processing Record 39 of Set 7 | pasni
# Processing Record 40 of Set 7 | chake chake
# Processing Record 41 of Set 7 | the valley
# Processing Record 42 of Set 7 | clyde river
# Processing Record 43 of Set 7 | yangambi
# Processing Record 44 of Set 7 | nelson bay
# Processing Record 45 of Set 7 | jomalig
# City not found. Skipping...
# Processing Record 46 of Set 7 | sabha
# Processing Record 47 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 48 of Set 7 | biggar
# Processing Record 49 of Set 7 | coari
# Processing Record 50 of Set 7 | nhamunda
# Processing Record 1 of Set 8 | aykhal
# Processing Record 2 of Set 8 | boca do acre
# Processing Record 3 of Set 8 | wagar
# Processing Record 4 of Set 8 | marrakesh
# Processing Record 5 of Set 8 | pacifica
# Processing Record 6 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 8 | miami
# Processing Record 8 of Set 8 | mozhaysk
# Processing Record 9 of Set 8 | gairo
# Processing Record 10 of Set 8 | pevek
# Processing Record 11 of Set 8 | ust-ilimsk
# Processing Record 12 of Set 8 | satis
# Processing Record 13 of Set 8 | katangli
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | port moresby
# Processing Record 16 of Set 8 | malinovoye ozero
# Processing Record 17 of Set 8 | palu
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | la primavera
# Processing Record 20 of Set 8 | balakhninskiy
# Processing Record 21 of Set 8 | huilong
# Processing Record 22 of Set 8 | kovdor
# Processing Record 23 of Set 8 | ballina
# Processing Record 24 of Set 8 | te anau
# Processing Record 25 of Set 8 | bengkulu
# Processing Record 26 of Set 8 | husavik
# Processing Record 27 of Set 8 | kloulklubed
# Processing Record 28 of Set 8 | carmarthen
# Processing Record 29 of Set 8 | saldanha
# Processing Record 30 of Set 8 | pangnirtung
# Processing Record 31 of Set 8 | tocopilla
# Processing Record 32 of Set 8 | bathsheba
# Processing Record 33 of Set 8 | rock springs
# Processing Record 34 of Set 8 | millau
# Processing Record 35 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 8 | barrow
# Processing Record 37 of Set 8 | male
# Processing Record 38 of Set 8 | banjarmasin
# Processing Record 39 of Set 8 | matara
# Processing Record 40 of Set 8 | saint-augustin
# Processing Record 41 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 8 | dimitrovgrad
# Processing Record 44 of Set 8 | eyl
# Processing Record 45 of Set 8 | batemans bay
# Processing Record 46 of Set 8 | aldan
# Processing Record 47 of Set 8 | daugai
# Processing Record 48 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 8 | ypsonas
# Processing Record 50 of Set 8 | aksay
# Processing Record 1 of Set 9 | noumea
# Processing Record 2 of Set 9 | saint george
# Processing Record 3 of Set 9 | nome
# Processing Record 4 of Set 9 | cidreira
# Processing Record 5 of Set 9 | stavern
# Processing Record 6 of Set 9 | khandagayty
# Processing Record 7 of Set 9 | jamsa
# Processing Record 8 of Set 9 | ambon
# Processing Record 9 of Set 9 | staffanstorp
# Processing Record 10 of Set 9 | manaure
# Processing Record 11 of Set 9 | mitu
# Processing Record 12 of Set 9 | east london
# Processing Record 13 of Set 9 | fakel
# Processing Record 14 of Set 9 | plavinas
# Processing Record 15 of Set 9 | sembabule
# Processing Record 16 of Set 9 | bac lieu
# Processing Record 17 of Set 9 | camalu
# Processing Record 18 of Set 9 | waipawa
# Processing Record 19 of Set 9 | fortuna
# Processing Record 20 of Set 9 | namibe
# Processing Record 21 of Set 9 | hamilton
# Processing Record 22 of Set 9 | rawson
# Processing Record 23 of Set 9 | ruwi
# Processing Record 24 of Set 9 | bartica
# Processing Record 25 of Set 9 | zarand
# Processing Record 26 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 9 | savannah bight
# Processing Record 28 of Set 9 | kargasok
# Processing Record 29 of Set 9 | san angelo
# Processing Record 30 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 9 | jabinyanah
# Processing Record 32 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 33 of Set 9 | punta alta
# Processing Record 34 of Set 9 | los llanos de aridane
# Processing Record 35 of Set 9 | dwarka
# Processing Record 36 of Set 9 | victor harbor
# Processing Record 37 of Set 9 | zhoucheng
# Processing Record 38 of Set 9 | jumla
# Processing Record 39 of Set 9 | tanout
# Processing Record 40 of Set 9 | anzhero-sudzhensk
# Processing Record 41 of Set 9 | maragogi
# Processing Record 42 of Set 9 | sapa
# Processing Record 43 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 9 | olafsvik
# Processing Record 45 of Set 9 | mus
# Processing Record 46 of Set 9 | werda
# Processing Record 47 of Set 9 | belaya gora
# Processing Record 48 of Set 9 | razole
# Processing Record 49 of Set 9 | mehamn
# Processing Record 50 of Set 9 | san joaquin
# Processing Record 1 of Set 10 | dunedin
# Processing Record 2 of Set 10 | grants
# Processing Record 3 of Set 10 | anadyr
# Processing Record 4 of Set 10 | mandalgovi
# Processing Record 5 of Set 10 | arica
# Processing Record 6 of Set 10 | zavetnoye
# Processing Record 7 of Set 10 | truth or consequences
# Processing Record 8 of Set 10 | orange cove
# Processing Record 9 of Set 10 | rio gallegos
# Processing Record 10 of Set 10 | lukovetskiy
# Processing Record 11 of Set 10 | necochea
# Processing Record 12 of Set 10 | empalme
# Processing Record 13 of Set 10 | lata
# Processing Record 14 of Set 10 | hauterive
# Processing Record 15 of Set 10 | caraballeda
# Processing Record 16 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 17 of Set 10 | tiznit
# Processing Record 18 of Set 10 | yeppoon
# Processing Record 19 of Set 10 | saint anthony
# Processing Record 20 of Set 10 | camacha
# Processing Record 21 of Set 10 | quelimane
# Processing Record 22 of Set 10 | libreville
# Processing Record 23 of Set 10 | floro
# Processing Record 24 of Set 10 | dabakala
# Processing Record 25 of Set 10 | teya
# Processing Record 26 of Set 10 | rio grande
# Processing Record 27 of Set 10 | tamiahua
# Processing Record 28 of Set 10 | dingle
# Processing Record 29 of Set 10 | mogapinyana
# Processing Record 30 of Set 10 | mount pleasant
# Processing Record 31 of Set 10 | tuatapere
# Processing Record 32 of Set 10 | trinidad
# Processing Record 33 of Set 10 | alihe
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | nuuk
# Processing Record 36 of Set 10 | hobyo
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | eydhafushi
# Processing Record 39 of Set 10 | posadas
# Processing Record 40 of Set 10 | sao joao da barra
# Processing Record 41 of Set 10 | piacabucu
# Processing Record 42 of Set 10 | miyako
# Processing Record 43 of Set 10 | kununurra
# Processing Record 44 of Set 10 | garowe
# Processing Record 45 of Set 10 | avondale
# Processing Record 46 of Set 10 | sakakah
# Processing Record 47 of Set 10 | cave
# Processing Record 48 of Set 10 | shagonar
# Processing Record 49 of Set 10 | meulaboh
# Processing Record 50 of Set 10 | pontes e lacerda
# Processing Record 1 of Set 11 | santo antonio do amparo
# Processing Record 2 of Set 11 | kisanga
# Processing Record 3 of Set 11 | kruisfontein
# Processing Record 4 of Set 11 | teguise
# Processing Record 5 of Set 11 | darhan
# Processing Record 6 of Set 11 | raudeberg
# Processing Record 7 of Set 11 | pochutla
# Processing Record 8 of Set 11 | wajir
# Processing Record 9 of Set 11 | luganville
# Processing Record 10 of Set 11 | hasaki
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | hay river
# Processing Record 13 of Set 11 | churapcha
# Processing Record 14 of Set 11 | turukhansk
# Processing Record 15 of Set 11 | tonj
# Processing Record 16 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 11 | lazaro cardenas
# Processing Record 18 of Set 11 | havelock
# Processing Record 19 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 20 of Set 11 | grand gaube
# Processing Record 21 of Set 11 | terney
# Processing Record 22 of Set 11 | berlevag
# Processing Record 23 of Set 11 | porto seguro
# Processing Record 24 of Set 11 | crixas
# Processing Record 25 of Set 11 | batsfjord
# Processing Record 26 of Set 11 | tornio
# Processing Record 27 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 28 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 11 | udachnyy
# Processing Record 30 of Set 11 | ketegyhaza
# Processing Record 31 of Set 11 | eyemouth
# Processing Record 32 of Set 11 | hovd
# Processing Record 33 of Set 11 | mitsamiouli
# Processing Record 34 of Set 11 | kholm-zhirkovskiy
# Processing Record 35 of Set 11 | kota belud
# Processing Record 36 of Set 11 | dudinka
# Processing Record 37 of Set 11 | sisimiut
# Processing Record 38 of Set 11 | pangkalanbuun
# Processing Record 39 of Set 11 | kerrobert
# Processing Record 40 of Set 11 | najran
# Processing Record 41 of Set 11 | saint-francois
# Processing Record 42 of Set 11 | bollnas
# Processing Record 43 of Set 11 | maraba
# Processing Record 44 of Set 11 | hanzhong
# Processing Record 45 of Set 11 | winton
# Processing Record 46 of Set 11 | itacoatiara
# Processing Record 47 of Set 11 | roebourne
# Processing Record 48 of Set 11 | dumas
# Processing Record 49 of Set 11 | bastrop
# Processing Record 50 of Set 11 | kaeo
# Processing Record 1 of Set 12 | voh
# Processing Record 2 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 3 of Set 12 | saint-joseph
# Processing Record 4 of Set 12 | comodoro rivadavia
# Processing Record 5 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 12 | logan lake
# Processing Record 7 of Set 12 | chichica
# Processing Record 8 of Set 12 | zhangye
# Processing Record 9 of Set 12 | shetpe
# Processing Record 10 of Set 12 | kushiro
# Processing Record 11 of Set 12 | houma
# Processing Record 12 of Set 12 | axim
# Processing Record 13 of Set 12 | chicama
# Processing Record 14 of Set 12 | iguape
# Processing Record 15 of Set 12 | labuhan
# Processing Record 16 of Set 12 | fare
# Processing Record 17 of Set 12 | bellevue
# Processing Record 18 of Set 12 | mwaro
# Processing Record 19 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 12 | airai
# Processing Record 21 of Set 12 | chekhov
# Processing Record 22 of Set 12 | georgiyevka
# Processing Record 23 of Set 12 | kamsack
# Processing Record 24 of Set 12 | nimes
# Processing Record 25 of Set 12 | san javier
# Processing Record 26 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 12 | sawtell
# Processing Record 28 of Set 12 | abu samrah
# Processing Record 29 of Set 12 | koryukivka
# Processing Record 30 of Set 12 | khandyga
# Processing Record 31 of Set 12 | podor
# Processing Record 32 of Set 12 | loreto
# Processing Record 33 of Set 12 | tabuk
# Processing Record 34 of Set 12 | hoquiam
# Processing Record 35 of Set 12 | acapulco
# Processing Record 36 of Set 12 | kieta
# Processing Record 37 of Set 12 | narsaq
# Processing Record 38 of Set 12 | mangrol
# Processing Record 39 of Set 12 | meilu
# City not found. Skipping...
# Processing Record 40 of Set 12 | george town
# Processing Record 41 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 42 of Set 12 | rongcheng
# Processing Record 43 of Set 12 | wanning
# Processing Record 44 of Set 12 | puerto cabezas
# Processing Record 45 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 46 of Set 12 | copiapo
# Processing Record 47 of Set 12 | alugan
# Processing Record 48 of Set 12 | carmo
# Processing Record 49 of Set 12 | punta de piedra
# Processing Record 50 of Set 12 | gabu
# Processing Record 1 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 2 of Set 13 | honningsvag
# Processing Record 3 of Set 13 | preobrazheniye
# Processing Record 4 of Set 13 | milkovo
# Processing Record 5 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 7 of Set 13 | san martin
# Processing Record 8 of Set 13 | lugovoy
# Processing Record 9 of Set 13 | zalantun
# Processing Record 10 of Set 13 | muisne
# Processing Record 11 of Set 13 | ust-kuyga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# {'coord': {'lon': 135.6, 'lat': 70.02}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 54.99, 'feels_like': 49.66, 'temp_min': 54.99, 'temp_max': 54.99, 'pressure': 1014, 'humidity': 69, 'sea_level': 1014, 'grnd_level': 1006}, 'wind': {'speed': 7.38, 'deg': 4}, 'clouds': {'all': 5}, 'dt': 1593361244, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 36000, 'id': 2013921, 'name': 'Ust-Kuyga', 'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness Current Weather  \
# 0    Kavieng  -2.57  150.80     82.53        79          35            Rain
# 1     Tiarei -17.53 -149.33     69.80        83          20          Clouds
# 2   Lalibela  12.03   39.03     66.96        51          81            Rain
# 3      Vaini -21.20 -175.20     75.20        94          75          Clouds
# 4       Hilo  19.73 -155.09     71.60        83          20          Clouds
# 5     Touros  -5.20  -35.46     84.20        66          75          Clouds
# 6   Luderitz -26.65   15.16     65.61        50           0           Clear
# 7  Busselton -33.65  115.33     50.00        92         100            Rain
# 8    Rikitea -23.12 -134.97     68.02        64           9           Clear
# 9  Namatanai  -3.67  152.43     79.50        79          77            Rain
#
#    Wind Speed Country                 Date  Rain  Snow
# 0       12.33      PG  2020-06-28 16:18:42  1.25     0
# 1        2.24      PF  2020-06-28 16:20:23  0.00     0
# 2        8.30      ET  2020-06-28 16:20:23  0.16     0
# 3        4.70      TO  2020-06-28 16:17:40  0.00     0
# 4        4.70      US  2020-06-28 16:15:46  0.00     0
# 5       10.29      BR  2020-06-28 16:15:31  0.00     0
# 6       23.76      NA  2020-06-28 16:17:35  0.00     0
# 7        1.01      AU  2020-06-28 16:17:29  0.18     0
# 8       19.86      PF  2020-06-28 16:16:45  0.00     0
# 9        6.87      PG  2020-06-28 16:18:52  0.77     0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
